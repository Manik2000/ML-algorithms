# %% [markdown]
# # PCA

# %%
import sys

sys.path.append("../..")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from matplotlib_inline.backend_inline import set_matplotlib_formats

from mlalgo.dimensionality_reduction.pca import PCA
from mlalgo.utils.helper_functions import standardize

# %%
sns.set_style("whitegrid")
set_matplotlib_formats("svg")

# %% [markdown]
# ## PCA for Iris dataset

# %%
iris_x, iris_y = load_iris(return_X_y=True)

# %%
sns.boxplot(iris_x)
plt.title("Iris dataset")
plt.show()

# %%
iris_x = standardize(iris_x)

pca = PCA(n_components=2)

iris_x_pca = pca.fit_transform(iris_x)

# %%
sns.scatterplot(x=iris_x_pca[:, 0], y=iris_x_pca[:, 1], hue=iris_y)
plt.title("PCA for Iris dataset")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.legend(title="Species")
plt.show()
